# %%
import pandas as pd

# %%
data = pd.read_excel('/content/AirQualityUCI.xlsx')

# %%
data
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0    2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1    2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2    2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3    2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4    2004-03-10  22:00:00     1.6      1272.25        51   6.518224
# ...         ...       ...     ...          ...       ...        ...
# 9352 2005-04-04  10:00:00     3.1      1314.25      -200  13.529605
# 9353 2005-04-04  11:00:00     2.4      1162.50      -200  11.355157
# 9354 2005-04-04  12:00:00     2.4      1142.00      -200  12.374538
# 9355 2005-04-04  13:00:00     2.1      1002.50      -200   9.547187
# 9356 2005-04-04  14:00:00     2.2      1070.75      -200  11.932060
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0           1045.50    166.0       1056.25    113.0       1692.00
# ...

# %%
data['NMHC(GT)'].value_counts()
# Out:
# -200    8443
#  66       14
#  40        9
#  29        9
#  88        8
#         ...
#  422       1
#  424       1
#  339       1
#  445       1
#  307       1
# Name: NMHC(GT), Length: 430, dtype: int64

# %%
data = data.drop('NMHC(GT)',axis=1)

# %%
data
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)   C6H6(GT)  PT08.S2(NMHC)  \
# 0    2004-03-10  18:00:00     2.6      1360.00  11.881723        1045.50
# 1    2004-03-10  19:00:00     2.0      1292.25   9.397165         954.75
# 2    2004-03-10  20:00:00     2.2      1402.00   8.997817         939.25
# 3    2004-03-10  21:00:00     2.2      1375.50   9.228796         948.25
# 4    2004-03-10  22:00:00     1.6      1272.25   6.518224         835.50
# ...         ...       ...     ...          ...        ...            ...
# 9352 2005-04-04  10:00:00     3.1      1314.25  13.529605        1101.25
# 9353 2005-04-04  11:00:00     2.4      1162.50  11.355157        1027.00
# 9354 2005-04-04  12:00:00     2.4      1142.00  12.374538        1062.50
# 9355 2005-04-04  13:00:00     2.1      1002.50   9.547187         960.50
# 9356 2005-04-04  14:00:00     2.2      1070.75  11.932060        1047.25
#
#       NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)       T  \
# ...

# %%
data = data.drop('CO(GT)',axis=1)

# %%
data
# Out:
#            Date      Time  PT08.S1(CO)   C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0    2004-03-10  18:00:00      1360.00  11.881723        1045.50    166.0
# 1    2004-03-10  19:00:00      1292.25   9.397165         954.75    103.0
# 2    2004-03-10  20:00:00      1402.00   8.997817         939.25    131.0
# 3    2004-03-10  21:00:00      1375.50   9.228796         948.25    172.0
# 4    2004-03-10  22:00:00      1272.25   6.518224         835.50    131.0
# ...         ...       ...          ...        ...            ...      ...
# 9352 2005-04-04  10:00:00      1314.25  13.529605        1101.25    471.7
# 9353 2005-04-04  11:00:00      1162.50  11.355157        1027.00    353.3
# 9354 2005-04-04  12:00:00      1142.00  12.374538        1062.50    293.0
# 9355 2005-04-04  13:00:00      1002.50   9.547187         960.50    234.5
# 9356 2005-04-04  14:00:00      1070.75  11.932060        1047.25    265.2
#
#       PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)       T         RH  \
# ...

# %%
X= data.drop(['Date','Time','C6H6(GT)'],axis=1)

# %%
X
# Out:
#       PT08.S1(CO)  PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  \
# 0         1360.00        1045.50    166.0       1056.25    113.0
# 1         1292.25         954.75    103.0       1173.75     92.0
# 2         1402.00         939.25    131.0       1140.00    114.0
# 3         1375.50         948.25    172.0       1092.00    122.0
# 4         1272.25         835.50    131.0       1205.00    116.0
# ...           ...            ...      ...           ...      ...
# 9352      1314.25        1101.25    471.7        538.50    189.8
# 9353      1162.50        1027.00    353.3        603.75    179.2
# 9354      1142.00        1062.50    293.0        603.25    174.7
# 9355      1002.50         960.50    234.5        701.50    155.7
# 9356      1070.75        1047.25    265.2        654.00    167.7
#
#       PT08.S4(NO2)  PT08.S5(O3)       T         RH        AH
# 0          1692.00      1267.50  13.600  48.875001  0.757754
# 1          1558.75       972.25  13.300  47.700000  0.725487
# ...

# %%
y= data['C6H6(GT)']

# %%
y
# Out:
# 0       11.881723
# 1        9.397165
# 2        8.997817
# 3        9.228796
# 4        6.518224
#           ...
# 9352    13.529605
# 9353    11.355157
# 9354    12.374538
# 9355     9.547187
# 9356    11.932060
# Name: C6H6(GT), Length: 9357, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

lr= LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([ 8.30814399,  5.52371372, 38.74895929, ...,  1.11607203,
#         8.32960697, 20.70160726])

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_test,y_pred)
# Out:
# 1.3714626375262449

# %%
lr.score(X_test, y_test)
# Out:
# 0.9990769725463866

# %%
lr.predict([[1402.00,939.25,131.0,1140.00,114.0,1554.50,1074.00,11.900,53.975000,0.750239]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([11.50732071])
